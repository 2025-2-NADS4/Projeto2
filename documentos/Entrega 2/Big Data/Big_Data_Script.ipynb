# %%
# === ETAPA 1: IMPORTAÇÕES E LEITURA DOS DADOS ===
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import json, ast
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="pandas")

# --- Leitura dos arquivos CSV (sep=";") ---
campaign = pd.read_csv("Campaign_API_ready.csv", sep=";", dtype=str)
cq       = pd.read_csv("CampaignQueue_API_ready.csv", sep=";", dtype=str)
customer = pd.read_csv("Customer_API_ready.csv", sep=";", dtype=str)
order    = pd.read_csv("Order_API_ready.csv", sep=";", dtype=str)

print("Arquivos carregados com sucesso!")
print(f"Campanhas: {campaign.shape}")
print(f"Mensagens: {cq.shape}")
print(f"Clientes: {customer.shape}")
print(f"Pedidos: {order.shape}")


# === ETAPA 2: LIMPEZA E PADRONIZAÇÃO DOS DADOS ===
# 2.1 normaliza nomes de colunas
for df in [campaign, cq, customer, order]:
    df.columns = df.columns.str.strip().str.lower()

# 2.2 conversão robusta de datas (sem format fixo para aceitar ISO com/sem milissegundos)
def parse_datetimes_flex(df):
    for col in df.columns:
        if (("at" in col) or ("date" in col)) and ("status" not in col):
            df[col] = pd.to_datetime(df[col], errors="coerce", utc=True)
    return df

campaign = parse_datetimes_flex(campaign)
cq       = parse_datetimes_flex(cq)
customer = parse_datetimes_flex(customer)
order    = parse_datetimes_flex(order)

# 2.3 utilitário seguro para números (evita erro com .str)
def to_num(series):
    """Converte string ou número para float, corrigindo vírgulas decimais."""
    if pd.api.types.is_numeric_dtype(series):
        return series
    return pd.to_numeric(series.astype(str).str.replace(",", ".", regex=False), errors="coerce")

# Ajuste de tipos de telefone
if "customerphone" in customer.columns:
    customer["customerphone"] = customer["customerphone"].astype(str)
if "phonenumber" in cq.columns:
    cq["phonenumber"] = cq["phonenumber"].astype(str)

print(" Dados padronizados e tipos ajustados!")


# === ETAPA 3: DERIVAÇÃO DE DADOS ===
# 3.1 DDD dos clientes (se houver telefone)
if "customerphone" in customer.columns:
    customer["ddd"] = customer["customerphone"].str[2:4]
else:
    customer["ddd"] = np.nan

# 3.2 Indicador de resposta (True/False) em CampaignQueue
cq["response"] = cq.get("response", "").astype(str).str.strip()
cq["tem_resposta"] = cq["response"].apply(lambda x: False if x.lower() in ["nan", "none", "", "null"] else True)

# 3.3 Hora do envio (se existir)
if "sendat" in cq.columns:
    cq["hora_envio"] = cq["sendat"].dt.hour
else:
    cq["hora_envio"] = np.nan

# 3.4 Converte colunas numéricas importantes
if "total.orderamount" in order.columns:
    order["total.orderamount"] = to_num(order["total.orderamount"])
if "preparationtime" in order.columns:
    order["preparationtime"] = to_num(order["preparationtime"])

# 3.5 Cálculo de tempo de preparo (preparationStartDateTime -> deliveryDateTime)
prep_start_col = "preparationstartdatetime" if "preparationstartdatetime" in order.columns else None
delivery_col   = "deliverydatetime" if "deliverydatetime" in order.columns else None

if prep_start_col and delivery_col:
    order["preparationtime_calc"] = (
        order[delivery_col] - order[prep_start_col]
    ).dt.total_seconds() / 60
    order["preparationtime_final"] = order["preparationtime"].fillna(order["preparationtime_calc"])
else:
    order["preparationtime_final"] = order.get("preparationtime")

print("⚙️ Conversão de datas e números finalizada com sucesso!")

# === ETAPA 4: INTEGRAÇÃO DOS DADOS ===
# 4.1 normaliza chaves como string
for col in ["id", "campaignid", "customerid"]:
    if col in cq.columns:       cq[col] = cq[col].astype(str).str.strip()
    if col in campaign.columns: campaign[col] = campaign[col].astype(str).str.strip()
    if col in customer.columns: customer[col] = customer[col].astype(str).str.strip()
    if col in order.columns:    order[col] = order[col].astype(str).str.strip()

# 4.2 merges
dados_integrados = cq.merge(
    campaign, left_on="campaignid", right_on="id", how="left", suffixes=("", "_camp")
)
dados_integrados = dados_integrados.merge(
    customer, left_on="customerid", right_on="id", how="left", suffixes=("", "_cust")
)

# order foi gerado com 'customer.id' como chave do cliente
order_key = "customer.id" if "customer.id" in order.columns else "customerid"
dados_integrados = dados_integrados.merge(
    order, left_on="customerid", right_on=order_key, how="left", suffixes=("", "_order")
)

print("Tabelas integradas com sucesso!")


# === ETAPA 5: FORMATAÇÃO FINAL (dataset analítico compacto) ===
colunas_finais = []
# escolhe colunas se existirem
for c in ["campaignid", "name", "badge", "type", "status",
          "customerid", "customerphone", "ddd", "tem_resposta",
          "hora_envio", "saleschannel", "total.orderamount"]:
    if c in dados_integrados.columns:
        colunas_finais.append(c)

df_final = dados_integrados[colunas_finais].copy() if colunas_finais else dados_integrados.copy()

# renomeia para nomes amigáveis
rename_map = {
    "name": "campanha",
    "badge": "categoria",
    "type": "tipo_campanha",
    "status": "status_campanha",
    "total.orderamount": "valor_pedido"
}
df_final = df_final.rename(columns={k:v for k,v in rename_map.items() if k in df_final.columns})

print("Dados formatados para análise!")


# === ETAPA 6: ANÁLISES ===
# 6.1 Tipos de campanha (mapeia 1/2)
if "type" in campaign.columns:
    camp_copy = campaign.copy()
    camp_copy["type"] = camp_copy["type"].replace({"1":"Promocional","2":"Institucional"})
    tipo_campanha = camp_copy["type"].value_counts(dropna=False).reset_index()
    tipo_campanha.columns = ["Tipo de Campanha", "Quantidade"]
else:
    tipo_campanha = pd.DataFrame({"Tipo de Campanha":[],"Quantidade":[]})

# 6.2 Status das campanhas
status_map = {"1":"Rascunho","2":"Cancelada","3":"Publicada","4":"Concluída"}
campaign["status_legivel"] = campaign.get("status","").map(status_map).fillna("Desconhecido")
status_camp = campaign["status_legivel"].value_counts(dropna=False).reset_index()
status_camp.columns = ["Status","Quantidade"]

# 6.3 Campanhas com maior taxa de resposta
if not df_final.empty and "campanha" in df_final.columns and "tem_resposta" in df_final.columns:
    campanhas_respostas = (
        df_final.dropna(subset=["campanha"])
                .groupby("campanha", dropna=False)["tem_resposta"]
                .mean()
                .reset_index()
    )
    campanhas_respostas["taxa_resposta_%"] = (campanhas_respostas["tem_resposta"]*100).round(2)
    campanhas_respostas = campanhas_respostas.sort_values("taxa_resposta_%", ascending=False)
else:
    campanhas_respostas = pd.DataFrame(columns=["campanha","tem_resposta","taxa_resposta_%"])

print("\n📊 Amostra de campanhas com respostas detectadas:")
print(campanhas_respostas.head(10))


# === ETAPA 7: VISUALIZAÇÕES ===
if not tipo_campanha.empty:
    fig1 = px.pie(
        tipo_campanha, names="Tipo de Campanha", values="Quantidade",
        title="📊 Tipos de Campanha", color_discrete_sequence=px.colors.qualitative.Pastel
    ); fig1.show()

if not status_camp.empty:
    fig2 = px.bar(
        status_camp, x="Status", y="Quantidade",
        title="📌 Status das Campanhas", text="Quantidade",
        color="Status", color_discrete_sequence=px.colors.qualitative.Safe
    ); fig2.update_traces(textposition="outside"); fig2.show()

if not campanhas_respostas.empty:
    top_n = campanhas_respostas.head(10)
    fig3 = px.bar(
        top_n, x="campanha", y="taxa_resposta_%",
        title="💬 Campanhas com Maior Taxa de Resposta (%)",
        text="taxa_resposta_%", color="taxa_resposta_%", color_continuous_scale="Blues"
    ); fig3.update_traces(textposition="outside"); fig3.show()
else:
    print("Nenhuma campanha com respostas válidas para exibir no gráfico.")

# Engajamento por DDD (se DDD existir)
if "ddd" in df_final.columns:
    engajamento_ddd = df_final.groupby("ddd", dropna=False)["tem_resposta"].mean().reset_index()
    engajamento_ddd["taxa_resposta_%"] = (engajamento_ddd["tem_resposta"]*100).round(2)
    fig4 = px.bar(
        engajamento_ddd, x="ddd", y="taxa_resposta_%",
        title="Engajamento por Região (DDD)",
        text="taxa_resposta_%", color="taxa_resposta_%", color_continuous_scale="Teal"
    ); fig4.update_traces(textposition="outside"); fig4.show()


# === ETAPA 8: INDICADORES GERAIS ===
# ticket médio
ticket_medio_geral = np.nan
if "total.orderamount" in order.columns:
    ticket_medio_geral = round(order["total.orderamount"].mean(skipna=True), 2)

# tempo médio bruto (preparationStartDateTime -> deliveryDateTime) OU baseado em preparationTime do CSV
tempo_medio = np.nan
if "preparationtime_final" in order.columns:
    tempo_medio = round(order["preparationtime_final"].mean(skipna=True), 2)

print("\n📈 === INDICADORES GERAIS ===")
print(f"⏱️ Tempo médio de preparo: {tempo_medio} minutos")
print(f"💸 Ticket médio: R$ {ticket_medio_geral}")


# === ETAPA 9: INDICADORES GERAIS ===
print("\n📈 === INDICADORES GERAIS ===")

# Ticket médio e tempo médio de preparo
order["total.orderamount"] = pd.to_numeric(order.get("total.orderamount", 0), errors="coerce")

# Usa a coluna calculada de tempo final
if "preparationtime_final" in order.columns:
    tempo_medio = round(order["preparationtime_final"].mean(skipna=True), 2)
else:
    tempo_medio = round(order.get("preparationtime", pd.Series([np.nan])).mean(skipna=True), 2)

ticket_medio_geral = round(order["total.orderamount"].mean(skipna=True), 2)

print(f"⏱️ Tempo médio de preparo: {tempo_medio if not np.isnan(tempo_medio) else 'N/D'} minutos")
print(f"💸 Ticket médio: R$ {ticket_medio_geral if not np.isnan(ticket_medio_geral) else 'N/D'}")

# === ETAPA 10: INSIGHTS AVANÇADOS ===
print("\n=== ETAPA 10: INSIGHTS AVANÇADOS ===")

def exists(df, cols):
    return all(c in df.columns for c in cols)

# 10.1 KPIs por canal
if exists(order, ["saleschannel", "total.orderamount", "preparationtime_final"]):
    kpis_canal = (order
        .groupby("saleschannel", dropna=False)
        .agg(
            pedidos=("id", "count") if "id" in order.columns else ("total.orderamount","count"),
            receita=("total.orderamount","sum"),
            ticket_medio=("total.orderamount","mean"),
            tempo_medio_preparo=("preparationtime_final","mean")
        )
        .reset_index()
        .sort_values("receita", ascending=False)
    )
    kpis_canal[["ticket_medio","tempo_medio_preparo"]] = kpis_canal[["ticket_medio","tempo_medio_preparo"]].round(2)

    print("\n📊 KPIs por Canal:")
    display(kpis_canal.head(10) if 'display' in globals() else kpis_canal.head(10))

    fig1 = px.bar(kpis_canal, x="saleschannel", y="receita",
                  title="💰 Receita por Canal",
                  text="receita", color="saleschannel")
    fig1.update_traces(texttemplate="R$ %{text:.2f}", textposition="outside")
    fig1.show()

    fig2 = px.bar(kpis_canal, x="saleschannel", y="tempo_medio_preparo",
                  title="⏱️ Tempo Médio de Preparo por Canal (min)",
                  text="tempo_medio_preparo", color="saleschannel")
    fig2.update_traces(texttemplate="%{text:.2f} min", textposition="outside")
    fig2.show()
else:
    print("Não foi possível calcular KPIs por canal.")

# 10.2 KPIs por loja
if "store.name" in order.columns and "total.orderamount" in order.columns:
    kpis_loja = (order
        .groupby("store.name", dropna=False)
        .agg(
            pedidos=("id", "count") if "id" in order.columns else ("total.orderamount","count"),
            receita=("total.orderamount","sum"),
            ticket_medio=("total.orderamount","mean"),
            tempo_medio=("preparationtime_final","mean") if "preparationtime_final" in order.columns else ("total.orderamount","size")
        )
        .reset_index()
        .sort_values("receita", ascending=False)
    )
    kpis_loja[["ticket_medio","tempo_medio"]] = kpis_loja[["ticket_medio","tempo_medio"]].round(2)

    print("\n🏪 KPIs por Loja:")
    display(kpis_loja.head(10) if 'display' in globals() else kpis_loja.head(10))

    fig3 = px.bar(kpis_loja.head(12), x="store.name", y="receita",
                  title="🏆 Top Lojas por Receita",
                  text="receita", color="store.name")
    fig3.update_traces(texttemplate="R$ %{text:.2f}", textposition="outside")
    fig3.update_layout(xaxis_tickangle=-30, showlegend=False)
    fig3.show()
else:
    print("⚠️ Não foi possível calcular KPIs por loja.")

# === 10.3 Heatmap de Engajamento por Hora e Dia da Semana ===
if "sendat" in cq.columns:
    # Extrai hora e dia da semana em português
    cq["hora"] = cq["sendat"].dt.hour
    cq["dia_semana"] = cq["sendat"].dt.day_name()

    # Tradução manual para português (sem depender do locale do sistema)
    dias_pt = {
        "Monday": "Segunda",
        "Tuesday": "Terça",
        "Wednesday": "Quarta",
        "Thursday": "Quinta",
        "Friday": "Sexta",
        "Saturday": "Sábado",
        "Sunday": "Domingo"
    }
    cq["dia_semana"] = cq["dia_semana"].map(dias_pt)

    # Agrupa para calcular média de respostas por hora e dia
    hm = (
        cq.groupby(["dia_semana", "hora"], dropna=False)["tem_resposta"]
        .mean()
        .reset_index()
    )
    hm["taxa_resposta_%"] = (hm["tem_resposta"] * 100).round(1)

    # Ordena os dias de forma cronológica (Seg → Dom)
    ordem_dias = ["Segunda", "Terça", "Quarta", "Quinta", "Sexta", "Sábado", "Domingo"]
    hm["dia_semana"] = pd.Categorical(hm["dia_semana"], categories=ordem_dias, ordered=True)
    hm = hm.sort_values(["dia_semana", "hora"])

    # Cria o heatmap
    fig4 = px.density_heatmap(
        hm,
        x="hora",
        y="dia_semana",
        z="taxa_resposta_%",
        title="Engajamento por Hora e Dia da Semana",
        nbinsx=24,
        histfunc="avg",
        color_continuous_scale="Blues",
        labels={"hora": "Hora do Envio", "dia_semana": "Dia da Semana", "taxa_resposta_%": "Taxa de Resposta (%)"}
    )

    fig4.update_layout(
        xaxis_title="Hora do Envio (0–23h)",
        yaxis_title="Dia da Semana",
        coloraxis_colorbar_title="Taxa de Resposta (%)",
        xaxis=dict(dtick=1)
    )
    fig4.show()
else:
    print("Heatmap não gerado: coluna 'sendAt' ausente em CampaignQueue.")


# 10.4 Conversão por campanha
if exists(dados_integrados, ["name","tem_resposta"]) and "total.orderamount" in dados_integrados.columns:
    conv_camp = (dados_integrados
        .groupby("name", dropna=False)
        .agg(
            mensagens=("id","count") if "id" in dados_integrados.columns else ("tem_resposta","count"),
            taxa_resposta=("tem_resposta","mean"),
            ticket_medio=("total.orderamount","mean")
        )
        .reset_index()
    )
    conv_camp["taxa_resposta_%"] = (conv_camp["taxa_resposta"]*100).round(1)
    conv_camp["ticket_medio"] = conv_camp["ticket_medio"].round(2)
    conv_camp = conv_camp.sort_values(["taxa_resposta_%","ticket_medio"], ascending=[False, False])

    print("\n🎯 Conversão por Campanha:")
    display(conv_camp.head(10) if 'display' in globals() else conv_camp.head(10))

    fig5 = px.scatter(conv_camp, x="taxa_resposta_%", y="ticket_medio",
                      size="mensagens", hover_name="name",
                      title="🎯 Campanhas: Taxa de Resposta (%) vs Ticket Médio (R$)")
    fig5.show()
else:
    print("Não foi possível gerar Conversão por Campanha.")

# 10.5 Funil de status de disparos
if "status" in cq.columns:
    status_map = {1:"Scheduled", 2:"Send", 3:"Received", 4:"Read", 5:"Deleted", 6:"Pending"}
    cq["status_legivel"] = cq["status"].map(status_map).fillna("Desconhecido")
    funil = cq["status_legivel"].value_counts(dropna=False).reset_index()
    funil.columns = ["Etapa","Quantidade"]

    print("\n🧭 Funil de Disparos:")
    display(funil if 'display' in globals() else funil)

    fig6 = px.funnel(funil, x="Quantidade", y="Etapa", title="🧭 Funil de Disparos")
    fig6.show()
else:
    print("Funil não gerado (status ausente).")

# 10.6 Impacto de Campanha em Pedidos (janela de 7 dias)
if exists(cq, ["customerid","sendat"]) and exists(order, ["customer.id","createdat","total.orderamount"]):
    base_msgs = cq[["customerid","sendat"]].dropna().rename(columns={"customerid":"cid"})
    base_ped  = order[["customer.id","createdat","total.orderamount"]].dropna().rename(columns={"customer.id":"cid"})
    merged = base_msgs.merge(base_ped, on="cid", how="left")

    within = merged[(merged["createdat"] >= merged["sendat"]) &
                    (merged["createdat"] <= merged["sendat"] + pd.Timedelta(days=7))]

    uplift = within["total.orderamount"].sum()
    pedidos_impacto = within.shape[0]

    print("\n📈 Impacto estimado (janela de 7 dias pós-envio):")
    print(f"- Pedidos atribuídos à campanha: {pedidos_impacto}")
    print(f"- Receita atribuída: R$ {round(uplift,2)}")
else:
    print("Skipping impacto em janela: colunas 'sendAt'/'createdAt' ausentes.")
# Out:
# ✅ Arquivos carregados com sucesso!
# Campanhas: (30, 17)
# Mensagens: (100, 16)
# Clientes: (100, 16)
# Pedidos: (100, 18)
# 🧹 Dados padronizados e tipos ajustados!
# ⚙️ Conversão de datas e números finalizada com sucesso!
# 🔗 Tabelas integradas com sucesso!
# 📦 Dados formatados para análise!
#
# 📊 Amostra de campanhas com respostas detectadas:
#                      campanha  tem_resposta  taxa_resposta_%
# 14      Semana do Café + Doce      1.000000           100.00
# 5            Cupom Pós-Evento      1.000000           100.00
# 8   Experimente Novos Sabores      0.875000            87.50
# 15         Semana do Pistache      0.809524            80.95
# 4    Comemore seu Aniversário      0.750000            75.00
# 2              Cliente do Mês      0.750000            75.00
# 12        Promoção do Domingo      0.666667            66.67
# 7   Entrega Grátis via 99Food      0.600000            60.00
# 6        Cupom de Boas-Vindas      0.583333            58.33
# 11           Festival do Doce      0.571429            57.14
# /tmp/ipython-input-3170155281.py:32: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", utc=True)
# /tmp/ipython-input-3170155281.py:32: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", utc=True)
# /tmp/ipython-input-3170155281.py:32: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", utc=True)
# /tmp/ipython-input-3170155281.py:32: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", utc=True)
# /tmp/ipython-input-3170155281.py:32: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", utc=True)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="261c80b7-5bee-427e-9e09-2960586b63f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("261c80b7-5bee-427e-9e09-2960586b63f1")) {                    Plotly.newPlot(                        "261c80b7-5bee-427e-9e09-2960586b63f1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Tipo de Campanha=%{label}\u003cbr\u003eQuantidade=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Institucional","Promocional"],"legendgroup":"","name":"","showlegend":true,"values":[15,15],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28f88764-430c-4599-9aeb-996ad1b1342c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28f88764-430c-4599-9aeb-996ad1b1342c")) {                    Plotly.newPlot(                        "28f88764-430c-4599-9aeb-996ad1b1342c",                        [{"alignmentgroup":"True","hovertemplate":"Status=%{x}\u003cbr\u003eQuantidade=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Concluída","marker":{"color":"rgb(136, 204, 238)","pattern":{"shape":""}},"name":"Concluída","offsetgroup":"Concluída","orientation":"v","showlegend":true,"text":[15.0],"textposition":"outside","x":["Concluída"],"xaxis":"x","y":[15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Status=%{x}\u003cbr\u003eQuantidade=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Publicada","marker":{"color":"rgb(204, 102, 119)","pattern":{"shape":""}},"name":"Publicada","offsetgroup":"Publicada","orientation":"v","showlegend":true,"text":[9.0],"textposition":"outside","x":["Publicada"],"xaxis":"x","y":[9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Status=%{x}\u003cbr\u003eQuantidade=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rascunho","marker":{"color":"rgb(221, 204, 119)","pattern":{"shape":""}},"name":"Rascunho","offsetgroup":"Rascunho","orientation":"v","showlegend":true,"text":[6.0],"textposition":"outside","x":["Rascunho"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6a178f56-ac59-4251-a4ad-e56b598e187a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a178f56-ac59-4251-a4ad-e56b598e187a")) {                    Plotly.newPlot(                        "6a178f56-ac59-4251-a4ad-e56b598e187a",                        [{"alignmentgroup":"True","hovertemplate":"campanha=%{x}\u003cbr\u003etaxa_resposta_%=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[100.0,100.0,87.5,80.95,75.0,75.0,66.67,60.0,58.33,57.14],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[100.0,100.0,87.5,80.95,75.0,75.0,66.67,60.0,58.33,57.14],"textposition":"outside","x":["Semana do Café + Doce","Cupom Pós-Evento","Experimente Novos Sabores","Semana do Pistache","Comemore seu Aniversário","Cliente do Mês","Promoção do Domingo","Entrega Grátis via 99Food","Cupom de Boas-Vindas","Festival do Doce"],"xaxis":"x","y":[100.0,100.0,87.5,80.95,75.0,75.0,66.67,60.0,58.33,57.14],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outl ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f07085c4-22ed-422f-afec-d1f090188a71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f07085c4-22ed-422f-afec-d1f090188a71")) {                    Plotly.newPlot(                        "f07085c4-22ed-422f-afec-d1f090188a71",                        [{"alignmentgroup":"True","hovertemplate":"ddd=%{x}\u003cbr\u003etaxa_resposta_%=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[62.16],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[62.16],"textposition":"outside","x":["11"],"xaxis":"x","y":[62.16],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outli ...
# 📈 === INDICADORES GERAIS ===
# ⏱️ Tempo médio de preparo: 64.13 minutos
# 💸 Ticket médio: R$ 94.27
#
# 📈 === INDICADORES GERAIS ===
# ⏱️ Tempo médio de preparo: 64.13 minutos
# 💸 Ticket médio: R$ 94.27
#
# === ETAPA 10: INSIGHTS AVANÇADOS ===
#
# 📊 KPIs por Canal:
#   saleschannel  pedidos  receita  ticket_medio  tempo_medio_preparo
# 2        IFOOD       44  4393.18         99.85                67.89
# 0       99FOOD       22  2352.97        106.95                53.45
# 4     WHATSAPP       24  1689.01         70.38                66.79
# 1  DELIVERYVIP        7   701.18        100.17                66.86
# 3         SITE        3   290.18         96.73                59.67
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f8cc50b-3b86-4a74-9a82-aa1f8c3258aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f8cc50b-3b86-4a74-9a82-aa1f8c3258aa")) {                    Plotly.newPlot(                        "5f8cc50b-3b86-4a74-9a82-aa1f8c3258aa",                        [{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IFOOD","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"IFOOD","offsetgroup":"IFOOD","orientation":"v","showlegend":true,"text":[4393.18],"textposition":"outside","x":["IFOOD"],"xaxis":"x","y":[4393.18],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"99FOOD","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"99FOOD","offsetgroup":"99FOOD","orientation":"v","showlegend":true,"text":[2352.97],"textposition":"outside","x":["99FOOD"],"xaxis":"x","y":[2352.97],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"WHATSAPP","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"WHATSAPP","offsetgroup":"WHATSAPP","orientation":"v","showlegend":true,"text":[1689.01],"textposition":"outside","x":["WHATSAPP"],"xaxis":"x","y":[1689.01],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DELIVERYVIP","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"DELIVERYVIP","offsetgroup":"DELIVERYVIP","orientation":"v","showlegend":true,"text":[701.1800000000001],"textposition":"outside","x":["DELIVERYVIP"],"xaxis":"x","y":[701.1800000000001],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SITE","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"SITE","offsetgroup":"SITE","orientation":"v","showlegend":true,"text":[290.17999999999995],"textposition":"outside","x":["SITE"],"xaxis":"x","y":[290.17999999999995],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"typ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bc92bdf4-8299-42de-b16b-eb583412cad3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc92bdf4-8299-42de-b16b-eb583412cad3")) {                    Plotly.newPlot(                        "bc92bdf4-8299-42de-b16b-eb583412cad3",                        [{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003etempo_medio_preparo=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IFOOD","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"IFOOD","offsetgroup":"IFOOD","orientation":"v","showlegend":true,"text":[67.89],"textposition":"outside","x":["IFOOD"],"xaxis":"x","y":[67.89],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f} min"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003etempo_medio_preparo=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"99FOOD","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"99FOOD","offsetgroup":"99FOOD","orientation":"v","showlegend":true,"text":[53.45],"textposition":"outside","x":["99FOOD"],"xaxis":"x","y":[53.45],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f} min"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003etempo_medio_preparo=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"WHATSAPP","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"WHATSAPP","offsetgroup":"WHATSAPP","orientation":"v","showlegend":true,"text":[66.79],"textposition":"outside","x":["WHATSAPP"],"xaxis":"x","y":[66.79],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f} min"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003etempo_medio_preparo=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DELIVERYVIP","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"DELIVERYVIP","offsetgroup":"DELIVERYVIP","orientation":"v","showlegend":true,"text":[66.86],"textposition":"outside","x":["DELIVERYVIP"],"xaxis":"x","y":[66.86],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f} min"},{"alignmentgroup":"True","hovertemplate":"saleschannel=%{x}\u003cbr\u003etempo_medio_preparo=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SITE","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"SITE","offsetgroup":"SITE","orientation":"v","showlegend":true,"text":[59.67],"textposition":"outside","x":["SITE"],"xaxis":"x","y":[59.67],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f} min"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{" ...
# 🏪 KPIs por Loja:
#                         store.name  pedidos  receita  ticket_medio  \
# 5                Masseria di Paolo       16  1973.28        123.33
# 1            Dona Nuvem Sobremesas       19  1363.97         71.79
# 13        Sabor de Casa Marmitaria        8   883.17        110.40
# 12            Sabor & Arte Doceria        9   767.93         85.33
# 0                  Bistrô da Praça        9   591.84         65.76
# 8                Panetteria Milano        6   587.77         97.96
# 4   Maria & João Padaria Artesanal        6   549.88         91.65
# 14                 The Urban Lunch        6   485.49         80.92
# 15              Trattoria Paulista        4   408.20        102.05
# 7                     Padoca do Zé        4   361.07         90.27
#
#     tempo_medio
# 5         55.44
# 1         58.16
# 13        69.00
# 12        80.11
# 0         64.22
# 8         86.17
# 4         57.83
# 14        52.83
# 15        37.25
# 7         66.50
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0df3abeb-0ffe-46f6-b101-604cc0d559fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0df3abeb-0ffe-46f6-b101-604cc0d559fe")) {                    Plotly.newPlot(                        "0df3abeb-0ffe-46f6-b101-604cc0d559fe",                        [{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Masseria di Paolo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Masseria di Paolo","offsetgroup":"Masseria di Paolo","orientation":"v","showlegend":true,"text":[1973.28],"textposition":"outside","x":["Masseria di Paolo"],"xaxis":"x","y":[1973.28],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dona Nuvem Sobremesas","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Dona Nuvem Sobremesas","offsetgroup":"Dona Nuvem Sobremesas","orientation":"v","showlegend":true,"text":[1363.97],"textposition":"outside","x":["Dona Nuvem Sobremesas"],"xaxis":"x","y":[1363.97],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sabor de Casa Marmitaria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Sabor de Casa Marmitaria","offsetgroup":"Sabor de Casa Marmitaria","orientation":"v","showlegend":true,"text":[883.1700000000001],"textposition":"outside","x":["Sabor de Casa Marmitaria"],"xaxis":"x","y":[883.1700000000001],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sabor & Arte Doceria","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Sabor & Arte Doceria","offsetgroup":"Sabor & Arte Doceria","orientation":"v","showlegend":true,"text":[767.9300000000001],"textposition":"outside","x":["Sabor & Arte Doceria"],"xaxis":"x","y":[767.9300000000001],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bistrô da Praça","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Bistrô da Praça","offsetgroup":"Bistrô da Praça","orientation":"v","showlegend":true,"text":[591.84],"textposition":"outside","x":["Bistrô da Praça"],"xaxis":"x","y":[591.84],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Panetteria Milano","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Panetteria Milano","offsetgroup":"Panetteria Milano","orientation":"v","showlegend":true,"text":[587.77],"textposition":"outside","x":["Panetteria Milano"],"xaxis":"x","y":[587.77],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u003cbr\u003ereceita=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maria & João Padaria Artesanal","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Maria & João Padaria Artesanal","offsetgroup":"Maria & João Padaria Artesanal","orientation":"v","showlegend":true,"text":[549.88],"textposition":"outside","x":["Maria & João Padaria Artesanal"],"xaxis":"x","y":[549.88],"yaxis":"y","type":"bar","texttemplate":"R$ %{text:.2f}"},{"alignmentgroup":"True","hovertemplate":"store.name=%{x}\u00 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2161b074-c05c-4d64-aaa3-761f68dfed50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2161b074-c05c-4d64-aaa3-761f68dfed50")) {                    Plotly.newPlot(                        "2161b074-c05c-4d64-aaa3-761f68dfed50",                        [{"coloraxis":"coloraxis","histfunc":"avg","hovertemplate":"Hora do Envio=%{x}\u003cbr\u003eDia da Semana=%{y}\u003cbr\u003eavg of Taxa de Resposta (%)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","nbinsx":24,"x":[0],"xaxis":"x","xbingroup":"x","y":["Sábado"],"yaxis":"y","ybingroup":"y","z":[60.0],"type":"histogram2d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpola ...
# 🎯 Conversão por Campanha:
#                          name  mensagens  taxa_resposta  ticket_medio  \
# 14      Semana do Café + Doce          9       1.000000        105.12
# 5            Cupom Pós-Evento          8       1.000000         93.38
# 8   Experimente Novos Sabores          8       0.875000        115.05
# 15         Semana do Pistache         21       0.809524         76.59
# 2              Cliente do Mês          4       0.750000        137.46
# 4    Comemore seu Aniversário          4       0.750000         72.23
# 12        Promoção do Domingo         12       0.666667         94.76
# 7   Entrega Grátis via 99Food          5       0.600000        136.59
# 6        Cupom de Boas-Vindas         12       0.583333        102.48
# 11           Festival do Doce          7       0.571429        115.48
#
#     taxa_resposta_%
# 14            100.0
# 5             100.0
# 8              87.5
# 15             81.0
# 2              75.0
# 4              75.0
# 12             66.7
# 7              60.0
# 6              58.3
# 11             57.1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90ebae77-8283-41e0-bbd5-5ea0fc94dd92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90ebae77-8283-41e0-bbd5-5ea0fc94dd92")) {                    Plotly.newPlot(                        "90ebae77-8283-41e0-bbd5-5ea0fc94dd92",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etaxa_resposta_%=%{x}\u003cbr\u003eticket_medio=%{y}\u003cbr\u003emensagens=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Semana do Café + Doce","Cupom Pós-Evento","Experimente Novos Sabores","Semana do Pistache","Cliente do Mês","Comemore seu Aniversário","Promoção do Domingo","Entrega Grátis via 99Food","Cupom de Boas-Vindas","Festival do Doce","Semana da Fidelização","Volte a Comprar com 15% OFF","Experiência Premium","Combo Família","Cashback da Madrugada","Cashback de Outubro","Festival do Chocolate","Sábado do Sabor"],"legendgroup":"","marker":{"color":"#636efa","size":[9,8,8,21,4,4,12,5,12,7,6,4,12,15,9,8,3,1],"sizemode":"area","sizeref":0.0525,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[100.0,100.0,87.5,81.0,75.0,75.0,66.7,60.0,58.3,57.1,50.0,50.0,50.0,46.7,44.4,12.5,0.0,0.0],"xaxis":"x","y":[105.12,93.38,115.05,76.59,137.46,72.23,94.76,136.59,102.48,115.48,113.66,101.26,80.57,92.91,90.54,145.75,145.82,59.32],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...
# 🧭 Funil de Disparos:
#           Etapa  Quantidade
# 0  Desconhecido         100
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ce9caa32-2f23-424e-9ea8-bae233f5b9d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce9caa32-2f23-424e-9ea8-bae233f5b9d2")) {                    Plotly.newPlot(                        "ce9caa32-2f23-424e-9ea8-bae233f5b9d2",                        [{"hovertemplate":"Quantidade=%{x}\u003cbr\u003eEtapa=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","orientation":"h","showlegend":false,"x":[100],"xaxis":"x","y":["Desconhecido"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram ...
# 📈 Impacto estimado (janela de 7 dias pós-envio):
# - Pedidos atribuídos à campanha: 116
# - Receita atribuída: R$ 11601.55
